# %% [markdown]
# # Import Packages

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
pd.set_option('display.max_rows', 500)

# %% [markdown]
# # Read Data

# %%
from google.colab import drive
drive.mount("/content/drive")

PATH = '/content/drive/MyDrive/Citadel Datathon/Data/Ziao/'
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df_raw = pd.read_csv(PATH+'data_raw.csv')
df_bid = pd.read_csv(PATH+'bidding.csv')

# %%
df_bid = df_bid[['match_id','match_result','match_result_rel']]
df_raw = pd.merge(df_raw, df_bid, on=['match_id'])

# %%
df_raw.date = pd.to_datetime(df_raw.date)

# %%
# Sort by date and match first to split
df_raw = df_raw.sort_values(by=['date','match_id'],ascending=True)
train_df = df_raw.iloc[:int(df_raw.shape[0]*0.7),:]
test_df = df_raw.iloc[int(df_raw.shape[0]*0.7):,:]

# %% [markdown]
# # Categorical Features

# %%
for c in train_df.columns:
  print(c)
# Out:
# match_id
# season
# stage
# date
# buildUpPlaySpeedDiff
# buildUpPlayPassingDiff
# chanceCreationPassingDiff
# chanceCreationCrossingDiff
# chanceCreationShootingDiff
# defencePressureDiff
# defenceAggressionDiff
# max_height_diff
# max_weight_diff
# max_overall_rating_diff
# max_potential_diff
# max_crossing_diff
# max_finishing_diff
# max_heading_accuracy_diff
# max_short_passing_diff
# max_volleys_diff
# max_dribbling_diff
# max_curve_diff
# max_free_kick_accuracy_diff
# max_long_passing_diff
# max_ball_control_diff
# max_acceleration_diff
# max_sprint_speed_diff
# max_agility_diff
# max_reactions_diff
# max_balance_diff
# max_shot_power_diff
# max_jumping_diff
# max_stamina_diff
# max_strength_diff
# max_long_shots_diff
# max_aggression_diff
# max_interceptions_diff
# max_positioning_diff
# max_vision_diff
# max_penalties_diff
# max_marking_diff
# max_standing_tackle_diff
# max_gk_diving_diff
# max_gk_handling_diff
# max_gk_kicking_diff
# max_gk_positioning_diff
# max_gk_reflexes_diff
# max_age_diff
# avg_height_diff
# avg_weight_diff
# avg_overall_rating_diff
# avg_potential_diff
# avg_crossing_diff
# avg_finishing_diff
# avg_heading_accuracy_diff
# avg_short_passing_diff
# avg_volleys_diff
# avg_dribbling_diff
# avg_curve_diff
# avg_free_kick_accuracy_diff
# avg_long_passing_diff
# avg_ball_control_diff
# avg_acceleration_diff
# avg_sprint_speed_diff
# avg_agility_diff
# avg_reactions_diff
# avg_balance_diff
# avg_shot_power_diff
# avg_jumping_diff
# avg_stamina_diff
# avg_strength_diff
# avg_long_shots_diff
# avg_aggression_diff
# avg_interceptions_diff
# avg_positioning_diff
# avg_vision_diff
# avg_penalties_diff
# avg_marking_diff
# avg_standing_tackle_diff
# avg_gk_diving_diff
# avg_gk_handling_diff
# avg_gk_kicking_diff
# avg_gk_positioning_diff
# avg_gk_reflexes_diff
# avg_age_diff
# std_height_diff
# std_weight_diff
# std_overall_rating_diff
# std_potential_diff
# std_crossing_diff
# std_finishing_diff
# std_heading_accuracy_diff
# std_short_passing_diff
# std_volleys_diff
# std_dribbling_diff
# std_curve_diff
# std_free_kick_accuracy_diff
# std_long_passing_diff
# std_ball_control_diff
# std_acceleration_diff
# std_sprint_speed_diff
# std_agility_diff
# std_reactions_diff
# std_balance_diff
# std_shot_power_diff
# std_jumping_diff
# std_stamina_diff
# std_strength_diff
# std_long_shots_diff
# std_aggression_diff
# std_interceptions_diff
# std_positioning_diff
# std_vision_diff
# std_penalties_diff
# std_marking_diff
# std_standing_tackle_diff
# std_gk_diving_diff
# std_gk_handling_diff
# std_gk_kicking_diff
# std_gk_positioning_diff
# std_gk_reflexes_diff
# std_age_diff
# home_mode_preferred_foot
# home_mode_attacking_work_rate
# home_mode_defensive_work_rate
# away_mode_preferred_foot
# away_mode_attacking_work_rate
# away_mode_defensive_work_rate
# match_result
# match_result_rel

# %%
id_cols = ['match_id','league_id','date','season']
target_cols = ['match_result','match_result_rel']
cat_cols = ["home_mode_preferred_foot", "home_mode_attacking_work_rate","home_mode_defensive_work_rate","away_mode_preferred_foot","away_mode_attacking_work_rate","away_mode_defensive_work_rate"]
num_cols = [i for i in train_df if i not in id_cols+target_cols+cat_cols and i != 'season']

# %%
from scipy.stats import chi2_contingency

def rolling_chisq(train_df,col,diff=600):
  total_rows = train_df.shape[0]
  ps = pd.Series(dtype='float64')
  for i in range(diff,total_rows, diff):
    try:
      _, p, _, _ = chi2_contingency(pd.crosstab(train_df.loc[i-diff:i,'match_result'], train_df.loc[i-diff:i,col]))
      ps = ps.append(pd.Series([p]))
    except:
      pass
  return ps

# %%
for c in cat_cols:
  res = rolling_chisq(train_df, c)
  print(c)
  print('Mean: %f, Std: %f'%(res.mean(),res.std()))
# Out:
# home_mode_preferred_foot
# Mean: 0.373815, Std: 0.314106
# home_mode_attacking_work_rate
# Mean: 0.215629, Std: 0.308639
# home_mode_defensive_work_rate
# Mean: 0.361291, Std: 0.287089
# away_mode_preferred_foot
# Mean: 0.379431, Std: 0.276110
# away_mode_attacking_work_rate
# Mean: 0.243813, Std: 0.273285
# away_mode_defensive_work_rate
# Mean: 0.268873, Std: 0.299511

# %%
# The categorical variables are not statistically related to target variable in a significant way and hence we can drop them

# %% [markdown]
# # Continuous Features

# %%
from scipy.stats import spearmanr

def rolling_cor(train_df,col,diff=600):
  total_rows = train_df.shape[0]
  cors = pd.Series(dtype='float64')
  ps = pd.Series(dtype='float64')
  for i in range(diff,total_rows, diff):
    try:
      cor,p = spearmanr(train_df.loc[i-diff:i,'match_result_rel'], train_df.loc[i-diff:i,col])
      cors = cors.append(pd.Series([cor]))
      ps = ps.append(pd.Series([p]))
    except:
      pass
  return cors, ps
res = pd.DataFrame(columns=['Feature','Cor Mean', 'Cor Std', 'P Value Mean', 'P Value Std'])
for c in num_cols:
  cors, ps = rolling_cor(train_df, c)
  res = pd.concat([res, pd.DataFrame([[c, cors.mean(), cors.std(), ps.mean(), ps.std()]],columns=['Feature','Cor Mean', 'Cor Std', 'P Value Mean', 'P Value Std'])])

# %%
res['Cor Mean'] = abs(res['Cor Mean'])

# %%
res['Cor Mean Rank'] = res['Cor Mean'].rank(ascending=False)
res['Cor Std Rank'] = res['Cor Std'].rank(ascending=True)
res['P Value Mean Rank'] = res['P Value Mean'].rank(ascending=True)
res['P Value Std Rank'] = res['P Value Std'].rank(ascending=True)

# %%
res['Total Rank'] = res['Cor Mean Rank'] + 0.5*res['Cor Std Rank'] + res['P Value Mean Rank'] + 0.5*res['P Value Std Rank']

# %%
res = res.sort_values(by=['Total Rank']).reset_index(drop=True)

# %%
res
# Out:
#                          Feature  Cor Mean  ...  P Value Std Rank  Total Rank
# 0             avg_potential_diff  0.365035  ...               7.0        13.5
# 1             avg_reactions_diff  0.356791  ...               2.0        15.5
# 2        max_overall_rating_diff  0.347166  ...               3.0        16.0
# 3        avg_overall_rating_diff  0.372563  ...               6.0        19.5
# 4         avg_short_passing_diff  0.348830  ...               9.0        28.0
# 5                avg_vision_diff  0.335127  ...               5.0        28.5
# 6          avg_ball_control_diff  0.353890  ...              16.0        32.5
# 7          avg_long_passing_diff  0.330469  ...              11.0        41.0
# 8             max_potential_diff  0.330025  ...              19.0        42.5
# 9             max_reactions_diff  0.312744  ...              17.0        46.5
# 10         max_ball_control_diff  0.319334  ...              23.0        50.0
# 11              avg_volleys_diff  0.312465  ...              13.0        51.0
# 12                avg_curve_diff  0.304224  ...               8.0        56.0
# 13               max_vision_diff  0.300441  ...              12.0        58.0
# 14              max_marking_diff  0.311950  ...               1.0        58.0
# 15          max_positioning_diff  0.285910  ...               4.0        60.0
# 16             avg_crossing_diff  0.303478  ...              25.0        66.5
# 17            avg_dribbling_diff  0.329685  ...              28.0        70.0
# 18        max_interceptions_diff  0.304340  ...              18.0        71.0
# 19              avg_agility_diff  0.270055  ...              24.0        72.0
# 20      max_standing_tackle_diff  0.307599  ...              14.0        72.5
# 21            avg_finishing_diff  0.298892  ...              30.0        74.0
# 22              std_marking_diff  0.283427  ...              26.0        77.0
# 23        max_short_passing_diff  0.306745  ...              31.0        78.5
# 24              max_volleys_diff  0.287007  ...              10.0        78.5
# 25             max_crossing_diff  0.255482  ...              22.0        79.0
# 26            avg_penalties_diff  0.282622  ...              15.0        80.0
# 27         avg_acceleration_diff  0.262592  ...              38.0        89.5
# 28            max_finishing_diff  0.283016  ...              20.0        91.0
# 29           avg_shot_power_diff  0.274677  ...              29.0        98.0
# 30         max_long_passing_diff  0.277290  ...              27.0       101.0
# 31            max_dribbling_diff  0.291445  ...              33.0       101.5
# 32     avg_heading_accuracy_diff  0.247928  ...              43.0       103.0
# 33           avg_long_shots_diff  0.283312  ...              34.0       108.5
# 34          avg_positioning_diff  0.296570  ...              35.0       110.0
# 35           max_long_shots_diff  0.246281  ...              37.0       113.5
# 36         avg_sprint_speed_diff  0.264791  ...              49.0       114.0
# 37           max_shot_power_diff  0.242007  ...              21.0       121.0
# 38       max_gk_positioning_diff  0.204846  ...              32.0       121.5
# 39   avg_free_kick_accuracy_diff  0.253046  ...              45.0       130.0
# 40              avg_stamina_diff  0.229364  ...              53.0       131.5
# 41        avg_interceptions_diff  0.235654  ...              42.0       131.5
# 42      std_standing_tackle_diff  0.225036  ...              39.0       133.0
# 43          max_gk_handling_diff  0.201355  ...              44.0       136.5
# 44                max_curve_diff  0.220030  ...              47.0       138.0
# 45       std_gk_positioning_diff  0.192702  ...              36.0       138.5
# 46            std_finishing_diff  0.185031  ...              40.0       139.0
# 47            max_gk_diving_diff  0.201366  ...              51.0       140.0
# 48          std_gk_handling_diff  0.188482  ...              52.0       146.5
# 49     max_heading_accuracy_diff  0.223514  ...              46.0       147.5
# 50           avg_aggression_diff  0.151035  ...              50.0       155.0
# 51              max_stamina_diff  0.193948  ...              41.0       157.5
# 52            std_gk_diving_diff  0.187692  ...              60.0       160.0
# 53           max_aggression_diff  0.159271  ...              56.0       161.0
# 54              max_agility_diff  0.207641  ...              48.0       164.0
# 55              avg_jumping_diff  0.164843  ...              66.0       167.0
# 56      avg_standing_tackle_diff  0.173360  ...              55.0       169.5
# 57          max_gk_reflexes_diff  0.188249  ...              67.0       178.5
# 58              std_volleys_diff  0.170031  ...              62.0       179.0
# 59         max_acceleration_diff  0.193365  ...              61.0       181.5
# 60              avg_balance_diff  0.185636  ...              54.0       189.5
# 61         std_ball_control_diff  0.162413  ...              58.0       191.0
# 62                std_curve_diff  0.161783  ...              57.0       192.5
# 63   std_free_kick_accuracy_diff  0.146251  ...              64.0       193.0
# 64            max_penalties_diff  0.200644  ...              63.0       194.0
# 65              avg_marking_diff  0.141515  ...              59.0       194.5
# 66          std_gk_reflexes_diff  0.177739  ...              70.0       203.0
# 67            std_dribbling_diff  0.149991  ...              71.0       208.5
# 68             avg_strength_diff  0.150035  ...              65.0       210.0
# 69             std_crossing_diff  0.156734  ...              68.0       216.0
# 70          std_positioning_diff  0.175904  ...              75.0       217.5
# 71         max_sprint_speed_diff  0.169295  ...              77.0       221.0
# 72     std_heading_accuracy_diff  0.183715  ...              80.0       224.0
# 73              max_balance_diff  0.158895  ...              69.0       226.0
# 74          avg_gk_reflexes_diff  0.081956  ...              84.0       226.5
# 75        std_short_passing_diff  0.080576  ...              90.0       227.0
# 76        std_interceptions_diff  0.204688  ...              88.0       228.0
# 77   max_free_kick_accuracy_diff  0.168427  ...              79.0       229.0
# 78           std_gk_kicking_diff  0.103929  ...              78.0       231.5
# 79          avg_gk_handling_diff  0.094616  ...              85.0       236.0
# 80       avg_gk_positioning_diff  0.102947  ...              76.0       239.5
# 81           max_gk_kicking_diff  0.141233  ...              72.0       241.0
# 82        buildUpPlayPassingDiff  0.093518  ...              82.0       249.5
# 83              max_jumping_diff  0.118016  ...              86.0       252.5
# 84             max_strength_diff  0.111374  ...              89.0       254.5
# 85            avg_gk_diving_diff  0.106297  ...              92.0       257.5
# 86           std_aggression_diff  0.074360  ...              94.0       259.5
# 87           defencePressureDiff  0.088911  ...              73.0       261.5
# 88               max_height_diff  0.092225  ...              81.0       262.0
# 89         std_long_passing_diff  0.044801  ...             105.0       265.0
# 90           std_long_shots_diff  0.140169  ...              97.0       266.0
# 91               std_vision_diff  0.118366  ...              87.0       267.0
# 92           avg_gk_kicking_diff  0.096213  ...              96.0       278.5
# 93               avg_weight_diff  0.045057  ...             107.0       280.0
# 94              std_agility_diff  0.056038  ...              95.0       281.5
# 95              std_stamina_diff  0.057383  ...              91.0       282.5
# 96               avg_height_diff  0.031487  ...             100.0       283.5
# 97               std_height_diff  0.086821  ...             101.0       285.5
# 98     chanceCreationPassingDiff  0.053057  ...              83.0       287.0
# 99               max_weight_diff  0.064217  ...             110.0       289.0
# 100         buildUpPlaySpeedDiff  0.014020  ...              74.0       289.5
# 101      std_overall_rating_diff  0.036211  ...             106.0       289.5
# 102              std_weight_diff  0.072151  ...             111.0       296.5
# 103        std_acceleration_diff  0.053449  ...             115.0       300.5
# 104        std_sprint_speed_diff  0.022228  ...             113.0       306.0
# 105           std_reactions_diff  0.047806  ...             104.0       307.0
# 106           std_potential_diff  0.024507  ...             119.0       307.0
# 107             std_balance_diff  0.060136  ...             118.0       308.5
# 108            std_strength_diff  0.040690  ...             117.0       311.5
# 109                 std_age_diff  0.042839  ...             102.0       312.0
# 110   chanceCreationShootingDiff  0.080212  ...             114.0       312.0
# 111   chanceCreationCrossingDiff  0.027815  ...              99.0       317.0
# 112           std_penalties_diff  0.033568  ...             108.0       319.0
# 113             std_jumping_diff  0.019224  ...              98.0       320.0
# 114                 avg_age_diff  0.019180  ...              93.0       322.5
# 115        defenceAggressionDiff  0.018154  ...             103.0       322.5
# 116                        stage  0.012455  ...             112.0       324.0
# 117          std_shot_power_diff  0.006375  ...             109.0       330.0
# 118                 max_age_diff  0.026190  ...             116.0       330.5
#
# [119 rows x 10 columns]

# %%
# 90 is a good cut off where the correlation starts to become lower than 0.1 and more statistical insignificant

# %%
final_num_cols = list(res.loc[:91, 'Feature'])

# %% [markdown]
# # Check Multicollinearity

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
def get_vif(train_df,cols):
  temp_df = train_df[cols]
  vif_data = pd.DataFrame()
  vif_data["feature"] = cols
  vif_data["VIF"] = [variance_inflation_factor(temp_df.values, i)
                            for i in range(len(temp_df.columns))]
  return vif_data

# %%
# Remove Variables until VIF value < 6
vif_data = get_vif(train_df, final_num_cols)
vif_data.sort_values(by='VIF',ascending=False).head()
# Out:
#                     feature         VIF
# 38  max_gk_positioning_diff  435.424942
# 45  std_gk_positioning_diff  364.771966
# 43     max_gk_handling_diff  361.934702
# 57     max_gk_reflexes_diff  349.487077
# 48     std_gk_handling_diff  300.591411

# %%
final_num_cols.remove('max_gk_positioning_diff')
vif_data = get_vif(train_df, final_num_cols)
vif_data.sort_values(by='VIF',ascending=False).head()
# Out:
#                  feature         VIF
# 42  max_gk_handling_diff  306.992226
# 56  max_gk_reflexes_diff  275.673629
# 46    max_gk_diving_diff  262.512929
# 47  std_gk_handling_diff  255.322425
# 65  std_gk_reflexes_diff  224.218601

# %%
final_num_cols.remove('max_gk_handling_diff')
vif_data = get_vif(train_df, final_num_cols)
vif_data.sort_values(by='VIF',ascending=False).head()
# Out:
#                     feature         VIF
# 45       max_gk_diving_diff  223.273418
# 55     max_gk_reflexes_diff  212.269422
# 50       std_gk_diving_diff  181.354594
# 64     std_gk_reflexes_diff  171.973224
# 3   avg_overall_rating_diff   48.376405

# %%
final_num_cols.remove('max_gk_diving_diff')
vif_data = get_vif(train_df, final_num_cols)
vif_data.sort_values(by='VIF',ascending=False).head()
# Out:
#                     feature        VIF
# 54     max_gk_reflexes_diff  52.017334
# 3   avg_overall_rating_diff  48.374517
# 63     std_gk_reflexes_diff  46.669630
# 6     avg_ball_control_diff  19.467728
# 0        avg_potential_diff  17.832488

# %%
final_num_cols.remove('max_gk_reflexes_diff')
vif_data = get_vif(train_df, final_num_cols)
vif_data.sort_values(by='VIF',ascending=False).head()
# Out:
#                     feature        VIF
# 3   avg_overall_rating_diff  48.315148
# 6     avg_ball_control_diff  19.466545
# 0        avg_potential_diff  17.825736
# 4    avg_short_passing_diff  15.657818
# 17       avg_dribbling_diff  11.332733

# %%
final_num_cols.remove('avg_overall_rating_diff')
vif_data = get_vif(train_df, final_num_cols)
vif_data.sort_values(by='VIF',ascending=False).head()
# Out:
#                     feature        VIF
# 5     avg_ball_control_diff  18.887803
# 0        avg_potential_diff  16.644834
# 3    avg_short_passing_diff  15.447248
# 16       avg_dribbling_diff  11.332585
# 2   max_overall_rating_diff   9.773237

# %%
final_num_cols.remove('avg_ball_control_diff')
vif_data = get_vif(train_df, final_num_cols)
vif_data.sort_values(by='VIF',ascending=False).head()
# Out:
#                     feature        VIF
# 0        avg_potential_diff  16.146953
# 3    avg_short_passing_diff  14.122345
# 2   max_overall_rating_diff   9.756790
# 15       avg_dribbling_diff   9.284425
# 5     avg_long_passing_diff   8.811253

# %%
final_num_cols.remove('avg_potential_diff')
vif_data = get_vif(train_df, final_num_cols)
vif_data.sort_values(by='VIF',ascending=False).head()
# Out:
#                     feature        VIF
# 2    avg_short_passing_diff  13.929623
# 1   max_overall_rating_diff   9.750171
# 14       avg_dribbling_diff   9.164300
# 4     avg_long_passing_diff   8.807891
# 0        avg_reactions_diff   8.559242

# %%
final_num_cols.remove('avg_short_passing_diff')
vif_data = get_vif(train_df, final_num_cols)
vif_data.sort_values(by='VIF',ascending=False).head()
# Out:
#                      feature       VIF
# 1    max_overall_rating_diff  9.672721
# 13        avg_dribbling_diff  8.862812
# 0         avg_reactions_diff  8.465050
# 23     avg_acceleration_diff  7.786318
# 49  avg_standing_tackle_diff  7.563813

# %%
final_num_cols.remove('max_overall_rating_diff')
vif_data = get_vif(train_df, final_num_cols)
vif_data.sort_values(by='VIF',ascending=False).head()
# Out:
#                      feature       VIF
# 12        avg_dribbling_diff  8.859350
# 0         avg_reactions_diff  8.449178
# 22     avg_acceleration_diff  7.780935
# 48  avg_standing_tackle_diff  7.537973
# 1            avg_vision_diff  7.467041

# %%
final_num_cols.remove('avg_dribbling_diff')
vif_data = get_vif(train_df, final_num_cols)
vif_data.sort_values(by='VIF',ascending=False).head()
# Out:
#                      feature       VIF
# 0         avg_reactions_diff  8.433902
# 21     avg_acceleration_diff  7.670399
# 47  avg_standing_tackle_diff  7.469410
# 1            avg_vision_diff  7.422251
# 2      avg_long_passing_diff  7.068585

# %%
final_num_cols.remove('avg_reactions_diff')
vif_data = get_vif(train_df, final_num_cols)
vif_data.sort_values(by='VIF',ascending=False).head()
# Out:
#                      feature       VIF
# 20     avg_acceleration_diff  7.630766
# 46  avg_standing_tackle_diff  7.468762
# 0            avg_vision_diff  7.299376
# 1      avg_long_passing_diff  7.027594
# 29     avg_sprint_speed_diff  6.582443

# %%
final_num_cols.remove('avg_acceleration_diff')
vif_data = get_vif(train_df, final_num_cols)
vif_data.sort_values(by='VIF',ascending=False).head()
# Out:
#                      feature       VIF
# 45  avg_standing_tackle_diff  7.456359
# 0            avg_vision_diff  7.298578
# 1      avg_long_passing_diff  7.026364
# 25       avg_long_shots_diff  6.441240
# 53          avg_marking_diff  5.893875

# %%
final_num_cols.remove('avg_standing_tackle_diff')
vif_data = get_vif(train_df, final_num_cols)
vif_data.sort_values(by='VIF',ascending=False).head()
# Out:
#                    feature       VIF
# 0          avg_vision_diff  7.296972
# 1    avg_long_passing_diff  7.006143
# 25     avg_long_shots_diff  6.437588
# 4    max_ball_control_diff  5.851743
# 16  max_short_passing_diff  5.382263

# %%
final_num_cols.remove('avg_vision_diff')
vif_data = get_vif(train_df, final_num_cols)
vif_data.sort_values(by='VIF',ascending=False).head()
# Out:
#                    feature       VIF
# 24     avg_long_shots_diff  6.435243
# 0    avg_long_passing_diff  6.365477
# 3    max_ball_control_diff  5.847814
# 15  max_short_passing_diff  5.380994
# 9        avg_crossing_diff  5.210146

# %%
final_num_cols.remove('avg_long_shots_diff')
vif_data = get_vif(train_df, final_num_cols)
vif_data.sort_values(by='VIF',ascending=False).head()
# Out:
#                    feature       VIF
# 0    avg_long_passing_diff  6.181940
# 3    max_ball_control_diff  5.847237
# 15  max_short_passing_diff  5.374557
# 9        avg_crossing_diff  5.204616
# 4         avg_volleys_diff  4.950182

# %%
final_num_cols.remove('avg_long_passing_diff')
vif_data = get_vif(train_df, final_num_cols)
vif_data.sort_values(by='VIF',ascending=False).head()
# Out:
#                    feature       VIF
# 2    max_ball_control_diff  5.835758
# 14  max_short_passing_diff  5.363890
# 3         avg_volleys_diff  4.949882
# 38      std_gk_diving_diff  4.901499
# 12      avg_finishing_diff  4.858577

# %%
final_num_cols.remove('max_ball_control_diff')
final_num_cols.remove('max_short_passing_diff')

# %% [markdown]
# # Output final Train and test

# %%
final_cols = id_cols + final_num_cols+ target_cols
train_df[final_cols].to_csv(PATH + 'train.csv',index=False)
test_df[final_cols].to_csv(PATH + 'test.csv',index=False)

# %%
train_df.shape
# Out:
# (11839, 131)

# %%
train_df[final_cols].shape
# Out:
# (11839, 80)

# %%
len(id_cols+target_cols)
# Out:
# 6
